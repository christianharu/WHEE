# %%
import pandas as pd
import os
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
import seaborn as sns
import sys
import numpy as np
from sentence_transformers import SentenceTransformer

import matplotlib.pyplot as plt

import warnings
from datasets import load_dataset
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import xgboost as xgb

from sklearn.feature_extraction.text import TfidfVectorizer
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Load Dataset

# %%
os.getcwd()
sys.argv[0]
dataset_dir = os.path.dirname(os.path.realpath('__file__'))+'/processed_datasets/'
train_dir = dataset_dir + '/train/'
test_dir = dataset_dir + '/test/'
valid_dir = dataset_dir + '/val/'

dataset_files = [train_dir + 'non_hri_data_train.csv',test_dir+ 'non_hri_data_test.csv', valid_dir + 'non_hri_data_val.csv']


vectorizer = TfidfVectorizer()

train_df = pd.read_csv(train_dir + 'non_hri_data_train.csv')
test_df = pd.read_csv(test_dir+ 'non_hri_data_test.csv')
valid_df = pd.read_csv(valid_dir + 'non_hri_data_val.csv')

hri_df = pd.read_csv(dataset_dir + '/hri_data_cues_revised_label.csv')

hri_df
# Out:
#                                                   text  ...  predictions_EX
# 0    That sounds very interesting. And do you often...  ...               2
# 1                     How long have you been together?  ...               2
# 2                                how can they do that?  ...               1
# 3    I hope that I can be there with you. Maybe can...  ...               0
# 4    it's great to hear that who do you go there with?  ...               2
# ..                                                 ...  ...             ...
# 611                             What do you listen to?  ...               2
# 612                             No, is it very famous?  ...               2
# 613  My favorite subject at school is English. I li...  ...               0
# 614  It sounds fun. What is your favorite thing to ...  ...               2
# 615  During Christmas, we meet up with family and w...  ...               0
#
# [616 rows x 10 columns]

# %%
X_train = vectorizer.fit_transform(train_df['text'])
X_test = vectorizer.transform(test_df['text'])
X_valid = vectorizer.transform(valid_df['text'])

X_hri = vectorizer.transform(hri_df['text'])


X_valid
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 62839 stored elements and shape (4882, 16673)>

# %% [markdown]
# ## Random Forest

# %%
model_rf = RandomForestClassifier(n_estimators=100, min_samples_split=3,criterion='gini')
model_rf.fit(X_train, train_df['label'])
# Out:
# RandomForestClassifier(min_samples_split=3)

# %%
def get_metrics(predicted, actual):
    accuracy = accuracy_score(actual, predicted)
    precision = precision_score(actual, predicted, average='macro')
    recall = recall_score(actual, predicted, average='macro')
    f1 = f1_score(actual, predicted, average='macro')
    print("Accuracy: {:.2f}%, Precision: {:.2f}% Recall: {:.2f}%, F1: {:.2f}%".format(accuracy * 100, precision *100, recall * 100, f1 *100))


predictions = model_rf.predict(X_test)

predictions_hri = model_rf.predict(X_hri)

print('metrics non-hri')
get_metrics(predictions,test_df['label'])
print('metrics hri')
get_metrics(predictions_hri,hri_df['revised_label'] )
# Out:
# metrics non-hri
# Accuracy: 70.32%, Precision: 64.96% Recall: 63.35%, F1: 63.55%
# metrics hri
# Accuracy: 46.75%, Precision: 60.02% Recall: 43.76%, F1: 38.43%

# %% [markdown]
# ## XGBoost

# %%
model_xg = xgb.XGBClassifier(n_jobs=-1,max_depth = 10, booster = 'gbtree', device = 'cpu', n_estimators = 100, objective= 'binary:logistic')
model_xg.fit(X_train, train_df['label'], eval_set=[(X_valid,valid_df['label'])])
# Out:
# [0]	validation_0-mlogloss:0.97811
# [1]	validation_0-mlogloss:0.90397
# [2]	validation_0-mlogloss:0.85419
# [3]	validation_0-mlogloss:0.81965
# [4]	validation_0-mlogloss:0.79435
# [5]	validation_0-mlogloss:0.77405
# [6]	validation_0-mlogloss:0.75826
# [7]	validation_0-mlogloss:0.74693
# [8]	validation_0-mlogloss:0.73663
# [9]	validation_0-mlogloss:0.72749
# [10]	validation_0-mlogloss:0.72004
# [11]	validation_0-mlogloss:0.71475
# [12]	validation_0-mlogloss:0.70964
# [13]	validation_0-mlogloss:0.70460
# [14]	validation_0-mlogloss:0.70035
# [15]	validation_0-mlogloss:0.69736
# [16]	validation_0-mlogloss:0.69425
# [17]	validation_0-mlogloss:0.69154
# [18]	validation_0-mlogloss:0.68930
# [19]	validation_0-mlogloss:0.68690
# [20]	validation_0-mlogloss:0.68427
# [21]	validation_0-mlogloss:0.68305
# [22]	validation_0-mlogloss:0.68100
# [23]	validation_0-mlogloss:0.67973
# [24]	validation_0-mlogloss:0.67717
# [25]	validation_0-mlogloss:0.67576
# [26]	validation_0-mlogloss:0.67395
# [27]	validation_0-mlogloss:0.67228
# [28]	validation_0-mlogloss:0.67020
# [29]	validation_0-mlogloss:0.66943
# [30]	validation_0-mlogloss:0.66812
# [31]	validation_0-mlogloss:0.66718
# [32]	validation_0-mlogloss:0.66591
# [33]	validation_0-mlogloss:0.66480
# [34]	validation_0-mlogloss:0.66397
# [35]	validation_0-mlogloss:0.66328
# [36]	validation_0-mlogloss:0.66277
# [37]	validation_0-mlogloss:0.66157
# [38]	validation_0-mlogloss:0.66033
# [39]	validation_0-mlogloss:0.65952
# [40]	validation_0-mlogloss:0.65869
# [41]	validation_0-mlogloss:0.65829
# [42]	validation_0-mlogloss:0.65712
# [43]	validation_0-mlogloss:0.65677
# [44]	validation_0-mlogloss:0.65606
# [45]	validation_0-mlogloss:0.65548
# [46]	validation_0-mlogloss:0.65458
# [47]	validation_0-mlogloss:0.65407
# [48]	validation_0-mlogloss:0.65338
# [49]	validation_0-mlogloss:0.65278
# [50]	validation_0-mlogloss:0.65283
# [51]	validation_0-mlogloss:0.65247
# [52]	validation_0-mlogloss:0.65274
# [53]	validation_0-mlogloss:0.65223
# [54]	validation_0-mlogloss:0.65171
# [55]	validation_0-mlogloss:0.65173
# [56]	validation_0-mlogloss:0.65110
# [57]	validation_0-mlogloss:0.65089
# [58]	validation_0-mlogloss:0.65056
# [59]	validation_0-mlogloss:0.65037
# [60]	validation_0-mlogloss:0.65021
# [61]	validation_0-mlogloss:0.65040
# [62]	validation_0-mlogloss:0.64964
# [63]	validation_0-mlogloss:0.64909
# [64]	validation_0-mlogloss:0.64885
# [65]	validation_0-mlogloss:0.64851
# [66]	validation_0-mlogloss:0.64805
# [67]	validation_0-mlogloss:0.64775
# [68]	validation_0-mlogloss:0.64738
# [69]	validation_0-mlogloss:0.64725
# [70]	validation_0-mlogloss:0.64702
# [71]	validation_0-mlogloss:0.64655
# [72]	validation_0-mlogloss:0.64610
# [73]	validation_0-mlogloss:0.64610
# [74]	validation_0-mlogloss:0.64555
# [75]	validation_0-mlogloss:0.64510
# [76]	validation_0-mlogloss:0.64529
# [77]	validation_0-mlogloss:0.64497
# [78]	validation_0-mlogloss:0.64473
# [79]	validation_0-mlogloss:0.64472
# [80]	validation_0-mlogloss:0.64485
# [81]	validation_0-mlogloss:0.64478
# [82]	validation_0-mlogloss:0.64477
# [83]	validation_0-mlogloss:0.64426
# [84]	validation_0-mlogloss:0.64382
# [85]	validation_0-mlogloss:0.64357
# [86]	validation_0-mlogloss:0.64381
# [87]	validation_0-mlogloss:0.64340
# [88]	validation_0-mlogloss:0.64333
# [89]	validation_0-mlogloss:0.64323
# [90]	validation_0-mlogloss:0.64307
# [91]	validation_0-mlogloss:0.64305
# [92]	validation_0-mlogloss:0.64268
# [93]	validation_0-mlogloss:0.64272
# [94]	validation_0-mlogloss:0.64251
# [95]	validation_0-mlogloss:0.64214
# [96]	validation_0-mlogloss:0.64217
# [97]	validation_0-mlogloss:0.64211
# [98]	validation_0-mlogloss:0.64192
# [99]	validation_0-mlogloss:0.64193
# XGBClassifier(base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device='cpu', early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=10,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=100,
#               n_jobs=-1, num_parallel_tree=None, ...)

# %%
predictions = model_xg.predict(X_test)
predictions_hri = model_xg.predict(X_hri)

print('metrics non-hri')
get_metrics(predictions,test_df['label'])
print('metrics hri')
get_metrics(predictions_hri,hri_df['revised_label'] )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 predictions = model_xg.predict(X_test)
#       2 accuracy = accuracy_score(test_df['label'], predictions)
#       3 print("Accuracy: {:.2f}%".format(accuracy * 100))
#
# NameError: name 'model_xg' is not defined
